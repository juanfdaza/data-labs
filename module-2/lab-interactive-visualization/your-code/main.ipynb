# %% [markdown]
# # Interactive Visualization Lab
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
import pandas as pd
import plotly.plotly as py
import cufflinks as cf
from ipywidgets import interact
import numpy as np

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel('../data/Online Retail.xlsx')
data.head()
# Out:
#    InvoiceNo         InvoiceDate StockCode  \
# 0     536365 2010-12-01 08:26:00    85123A
# 1     536373 2010-12-01 09:02:00    85123A
# 2     536375 2010-12-01 09:32:00    85123A
# 3     536390 2010-12-01 10:19:00    85123A
# 4     536394 2010-12-01 10:39:00    85123A
#
#                           Description  Quantity  UnitPrice  Revenue  \
# 0  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 1  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 2  CREAM HANGING HEART T-LIGHT HOLDER         6       2.55     15.3
# 3  CREAM HANGING HEART T-LIGHT HOLDER        64       2.55    163.2
# 4  CREAM HANGING HEART T-LIGHT HOLDER        32       2.55     81.6
#
#    CustomerID         Country
# 0       17850  United Kingdom
# 1       17850  United Kingdom
# 2       17850  United Kingdom
# 3       17511  United Kingdom
# 4       13408  United Kingdom

# %% [markdown]
# ## 1. Create an interactive bar chart showing total quantity and revenue by country (excluding United Kingdom) for the month of April 2011.

# %%
data['InvoiceDate'] = data['InvoiceDate'].apply(lambda x: pd.to_datetime(x,format='%Y%m%d'))

# %%
data.dtypes
# Out:
# InvoiceNo               int64
# InvoiceDate    datetime64[ns]
# StockCode              object
# Description            object
# Quantity                int64
# UnitPrice             float64
# Revenue               float64
# CustomerID              int64
# Country                object
# dtype: object

# %%
countries_list = list(data['Country'].unique())
countries_list.remove('United Kingdom')

# %%
data.loc[(data['InvoiceDate']>'2011-04-30') &\
         (data['Country'].isin(countries_list))].pivot_table(index = 'Country',\
                                                             values = ('Quantity','Revenue'),\
                                                             aggfunc = 'sum').iplot(kind = 'bar',\
                                                                                   xTitle = 'Country',
                                                                                   yTitle = 'Quantity',
                                                                                   title = 'Units & Revenue by Country',
                                                                                   subplots = True)
# Out:
# <div>
#
#
#             <div id="d9790694-26c6-45ff-a0b4-497f071af206" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d9790694-26c6-45ff-a0b4-497f071af206")) {
#                     Plotly.newPlot(
#                         'd9790694-26c6-45ff-a0b4-497f071af206',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Quantity", "orientation": "v", "text": "", "type": "bar", "uid": "610a1689-69d3-463a-b2df-c23215e1eff4", "x": ["Australia", "Austria", "Bahrain", "Belgium", "Canada", "Channel Islands", "Cyprus", "Czech Republic", "Denmark", "EIRE", "Finland", "France", "Germany", "Greece", "Iceland", "Israel", "Italy", "Japan", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Singapore", "South Africa", "Spain", "Sweden", "Switzerland", "USA", "United Arab Emirates"], "xaxis": "x", "y": [58446, 3176, 260, 16421, 2674, 6014, 2104, 324, 6646, 107822, 5127, 80390, 84823, 475, 1341, 3760, 5222, 10845, 958, 140082, 15249, 2356, 9858, 2759, 351, 18710, 23035, 23323, 2321, 485], "yaxis": "y"}, {"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "Revenue", "orientation": "v", "text": "", "type": "bar", "uid": "1fb27c0c-fdb5-4ea2-9e7a-a001365d95ba", "x": ["Australia", "Austria", "Bahrain", "Belgium", "Canada", "Channel Islands", "Cyprus", "Czech Republic", "Denmark", "EIRE", "Finland", "France", "Germany", "Greece", "Iceland", "Israel", "Italy", "Japan", "Malta", "Netherlands", "Norway", "Poland", "Portugal", "Singapore", "South Africa", "Spain", "Sweden", "Switzerland", "USA", "United Arab Emirates"], "xaxis": "x2", "y": [95779.73999999993, 6254.220000000002, 548.4, 27537.699999999964, 2974.900000000001, 13481.28999999996, 6179.429999999998, 237.48, 12731.629999999981, 191981.44999999617, 10523.359999999984, 133910.42999999982, 144281.38, 867.2300000000002, 2486.570000000001, 6442.590000000004, 10460.589999999991, 17333.089999999997, 2070.5899999999997, 200613.73999999923, 27731.610000000037, 4485.6, 15953.769999999933, 4948.579999999999, 1002.3099999999997, 36183.99000000019, 23919.52999999998, 41463.710000000145, 3196.440000000002, 975.5400000000001], "yaxis": "y2"}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "
# 252866     537128 2010-12-05 12:15:00     47566  PARTY BUNTING         2
# 252867     537142 2010-12-05 12:57:00     47566  PARTY BUNTING         1
# 252868     537420 2010-12-06 15:18:00     47566  PARTY BUNTING         5
#
#         UnitPrice  Revenue  CustomerID         Country
# 252864       4.65    23.25       14210  United Kingdom
# 252865       4.65    23.25       12567          France
# 252866       4.65     9.30       12841  United Kingdom
# 252867       4.65     4.65       12748  United Kingdom
# 252868       4.65    23.25       17519  United Kingdom

# %%
pivot_PB= data.loc[(data['Description']=='PARTY BUNTING')].pivot_table(columns='Country',
                                                             values = ('Quantity','UnitPrice'),
                                                             aggfunc = 'mean')

# %%
data.loc[data['Description']=='PARTY BUNTING',['Country','Quantity','UnitPrice']].groupby(['Country'], as_index = False).agg('mean')
# Out:
#             Country   Quantity  UnitPrice
# 0         Australia  33.125000   4.712500
# 1           Austria   8.000000   4.950000
# 2           Belgium   4.000000   4.950000
# 3   Channel Islands  13.333333   4.950000
# 4            Cyprus   2.333333   4.750000
# 5           Denmark  12.000000   4.950000
# 6              EIRE  21.210526   4.739474
# 7           Finland   6.000000   4.950000
# 8            France   5.727273   4.922727
# 9           Germany   6.800000   4.890000
# 10           Israel   1.000000   4.950000
# 11            Japan  56.666667   4.183333
# 12          Lebanon  15.000000   4.650000
# 13      Netherlands  50.000000   4.150000
# 14           Norway   6.000000   4.950000
# 15        Singapore   8.000000   4.950000
# 16     South Africa   4.000000   4.950000
# 17            Spain   4.750000   4.837500
# 18      Switzerland  17.200000   4.790000
# 19   United Kingdom  10.705432   4.880926

# %%
data.loc[data['Description']=='PARTY BUNTING',
         ['Country','Quantity','UnitPrice']].groupby(['Country'],as_index = False).agg('mean').iplot(x = 'Quantity', 
                                                                                    y = 'UnitPrice',
                                                                                    xTitle = 'Quantity',
                                                                                    yTitle = 'UnitPrice',
                                                                                    title = 'Relationshio btween Qty & UnitPrice',
                                                                                    categories = 'Country')
# Out:
# <div>
#
#
#             <div id="c83e13f2-43db-4f05-9d31-d999dfed6743" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c83e13f2-43db-4f05-9d31-d999dfed6743")) {
#                     Plotly.newPlot(
#                         'c83e13f2-43db-4f05-9d31-d999dfed6743',
#                         [{"marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Australia", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "1fd8f44a-2365-4eef-90f8-748d9ef3a0c1", "x": [33.125], "y": [4.7125]}, {"marker": {"color": "rgba(55, 128, 191, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Austria", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "b8544b72-b1bc-47fd-bad1-4fb6fb3ec4de", "x": [8.0], "y": [4.95]}, {"marker": {"color": "rgba(50, 171, 96, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Belgium", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "cf874a99-7463-4f93-9b8a-df508e3feb8d", "x": [4.0], "y": [4.95]}, {"marker": {"color": "rgba(128, 0, 128, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Channel Islands", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "23b8d108-7398-4181-8745-59afaddd30df", "x": [13.333333333333334], "y": [4.95]}, {"marker": {"color": "rgba(219, 64, 82, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Cyprus", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "e37211f0-f631-4dd3-9dd2-8a4d20faa392", "x": [2.3333333333333335], "y": [4.75]}, {"marker": {"color": "rgba(0, 128, 128, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Denmark", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "c98312e5-ed9c-40f8-a37f-3aa183afe5cb", "x": [12.0], "y": [4.95]}, {"marker": {"color": "rgba(255, 255, 51, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "EIRE", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "5c908813-6f12-4884-98ed-e0e1cc7aeb4a", "x": [21.210526315789473], "y": [4.739473684210528]}, {"marker": {"color": "rgba(128, 128, 0, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Finland", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "ac52958b-7dea-4473-a220-f7082ca946df", "x": [6.0], "y": [4.95]}, {"marker": {"color": "rgba(251, 128, 114, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "France", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "fb612fcc-e67e-482d-b602-08854f524e7d", "x": [5.7272727272727275], "y": [4.922727272727275]}, {"marker": {"color": "rgba(128, 177, 211, 1.0)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Germany", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "6cf2e346-a996-45a7-8ce9-567953d85255", "x": [6.8], "y": [4.89]}, {"marker": {"color": "rgba(128, 177, 211, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Israel", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "a75dc53b-c822-4800-b807-d5f554a63999", "x": [1.0], "y": [4.95]}, {"marker": {"color": "rgba(255, 153, 51, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Japan", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "c331715b-65a3-4df5-b6bc-df4e19e65e9c", "x": [56.666666666666664], "y": [4.183333333333334]}, {"marker": {"color": "rgba(55, 128, 191, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "size": 12, "symbol": "circle"}, "mode": "markers", "name": "Lebanon", "textfont": {"color": "#4D5663"}, "type": "scatter", "uid": "46b63ba9-8fb6-4370-a8a9-94c0008d9ce6", "x": [15.0], "y": [4.65]}, {"marker": {"color": "rgba(50, 171, 96, 0.8999999999999999)", "line": {"width": 1.3}, "opacity": 0.8, "s ...
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Relationshio btween Qty & UnitPrice"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Quantity"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "UnitPrice"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c83e13f2-43db-4f05-9d31-d999dfed6743');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clea

# %% [markdown]
# ## 4. Create a set of interactive histograms showing the distributions of quantity per invoice for the following countries: EIRE, Germany, France, and Netherlands.

# %%
# First lets create a list of countries to be included in the analysis
country_list = ['EIRE','Germany','France','Netherlands']

# %%
# Now lets plot a graph for each country
data.loc[(data['Country'].isin(country_list))].pivot_table(index = 'InvoiceNo',columns = 'Country',
                                                           values = ('Quantity'),
                                                           aggfunc = 'count').iplot(kind = 'hist',
                                                                           xTitle = 'Invoice',
                                                                           yTitle = 'Qty per Invoice',
                                                                           title = 'Distrib of Qty per Invoice per country',
                                                                           subplots = True)
# Out:
# <div>
#
#
#             <div id="e53efc4a-ed67-45b3-8663-f33a7dd34322" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e53efc4a-ed67-45b3-8663-f33a7dd34322")) {
#                     Plotly.newPlot(
#                         'e53efc4a-ed67-45b3-8663-f33a7dd34322',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "name": "EIRE", "opacity": 0.8, "orientation": "v", "type": "histogram", "uid": "0cca10ee-e5f3-443b-b8d0-bc3d12f73fee", "x": [null, null, null, 19.0, 1.0, 1.0, null, null, null, 3.0, null, null, 71.0, null, null, null, null, null, null, null, 14.0, 19.0, 1.0, null, null, null, null, null, null, null, null, null, null, null, 32.0, null, null, null, 51.0, null, null, null, 18.0, null, null, null, null, null, null, null, null, 38.0, null, null, null, 17.0, null, null, null, null, 28.0, null, null, null, null, null, 14.0, null, null, null, null, null, null, null, null, null, null, null, 12.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 41.0, null, null, null, null, 9.0, null, null, null, null, null, null, 21.0, null, null, null, null, null, 14.0, null, null, null, null, null, 52.0, null, 20.0, null, null, null, null, null, null, null, null, null, null, null, null, null, 45.0, null, null, null, null, null, null, null, null, 40.0, null, 12.0, null, null, null, null, null, null, null, null, null, 76.0, null, null, null, 110.0, 23.0, null, null, 13.0, null, null, null, null, 9.0, null, null, null, null, null, null, null, null, 15.0, null, null, null, null, null, null, null, null, null, null, null, null, null, 6.0, null, null, null, null, null, 18.0, 56.0, null, null, null, null, null, null, null, 29.0, 27.0, 3.0, 3.0, null, null, null, null, null, 30.0, 41.0, 29.0, 45.0, 24.0, 27.0, null, null, null, null, null, null, 24.0, 44.0, null, null, null, null, null, 10.0, null, null, null, null, null, null, null, null, null, null, null, null, null, 15.0, null, null, 43.0, null, null, null, null, null, 38.0, null, null, null, null, null, null, null, null, null, null, null, 8.0, null, null, null, null, null, 67.0, 14.0, null, null, null, 14.0, null, null, 65.0, null, 22.0, 10.0, null, null, null, null, 49.0, null, 11.0, null, null, null, null, null, null, null, 24.0, null, null, null, 20.0, null, null, null, null, null, null, null, null, null, 4.0, null, null, null, null, null, null, null, null, null, null, 37.0, 31.0, null, null, null, null, null, null, 22.0, null, 20.0, null, 49.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 17.0, 32.0, null, 32.0, null, 35.0, 39.0, null, null, null, null, null, null, 60.0, null, null, null, null, null, null, null, null, 15.0, 30.0, 22.0, null, null, null, null, null, null, null, null, 52.0, null, null, null, null, null, null, null, null, null, null, null, null, null, 25.0, 1.0, 1.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 45.0, null, 12.0, null, null, null, null, 57.0, 8.0, null, null, 21.0, 25.0, null, null, null, null, null, null, null, null, null, 42.0, null, null, null, null, null, null, null, null, 27.0, 4.0, 33.0, null, null, null, 32.0, null, null, null, 13.0, null, null, null, null, null, null, 2.0, null, null, null, 18.0, 27.0, null, 18.0, 1.0, null, null, 37.0, 4.0, null, 34.0, 12.0, null, null, null, null, null, 25.0, 3.0, null, 30.0, null, null, 7.0, 1.0, 45.0, null, null, null, null, null, 6.0, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, 47.0, null, 27.0, null, null, null, null, 67.0, null, null, 60.0, 3.0, 68.0, null, 24.0, null, null, null, null, null, null, null, null, null, 19.0, null, 9.0, 11.0, null, null, null, null, null, 6.0, null, null, 20.0, 4.0, null, 28.0, 31.0, null, 25.0, 80.0, 19.0, null, null, null, null, null, null, null, null, null, 31.0, null, null, null, null, null, 147.0, null, null, 58.0, null, null, null, null, 21.0, 26.0, 9.0, null, 41.0,  ...

# %% [markdown]
# ## 5. Create an interactive side-by-side bar chart showing the revenue by country listed below (bars) for each of the products listed below.

# %%
product_list = ['JUMBO BAG RED RETROSPOT', 
                'CREAM HANGING HEART T-LIGHT HOLDER',
                'REGENCY CAKESTAND 3 TIER']

country_list = ['EIRE', 'Germany', 'France', 'Netherlands']

# %%
data.loc[(data['Country'].isin(country_list)) &\
         data['Description'].isin(product_list)
         ,['Country','Description','Revenue']].groupby(['Country','Description'],as_index=False).agg({'Revenue':'sum'})
# Out:
#         Country                         Description  Revenue
# 0          EIRE  CREAM HANGING HEART T-LIGHT HOLDER  2740.80
# 1          EIRE             JUMBO BAG RED RETROSPOT   278.72
# 2          EIRE            REGENCY CAKESTAND 3 TIER  7388.55
# 3        France  CREAM HANGING HEART T-LIGHT HOLDER   131.75
# 4        France             JUMBO BAG RED RETROSPOT   903.37
# 5        France            REGENCY CAKESTAND 3 TIER  2816.85
# 6       Germany  CREAM HANGING HEART T-LIGHT HOLDER    35.40
# 7       Germany             JUMBO BAG RED RETROSPOT  1072.76
# 8       Germany            REGENCY CAKESTAND 3 TIER  9061.95
# 9   Netherlands  CREAM HANGING HEART T-LIGHT HOLDER  1167.00
# 10  Netherlands             JUMBO BAG RED RETROSPOT  3468.00
# 11  Netherlands            REGENCY CAKESTAND 3 TIER  3166.35

# %%
data.loc[(data['Country'].isin(country_list)) &\
         data['Description'].isin(product_list)
         ,['Country','Description','Revenue']].groupby(['Country','Description'],as_index=False).agg({'Revenue':'sum'}).\
         iplot(kind = 'bar',
               x = ('Country'),
               y = 'Revenue',
              color = ['blue','red','green'])
# Out:
# <div>
#
#
#             <div id="06ed558c-4d2e-41c5-b5c0-7d9a649cde70" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("06ed558c-4d2e-41c5-b5c0-7d9a649cde70")) {
#                     Plotly.newPlot(
#                         '06ed558c-4d2e-41c5-b5c0-7d9a649cde70',
#                         [{"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "Revenue", "orientation": "v", "text": "", "type": "bar", "uid": "f8d5ca2c-a811-4b2c-a35b-f8a3c9f9549e", "x": ["EIRE", "EIRE", "EIRE", "France", "France", "France", "Germany", "Germany", "Germany", "Netherlands", "Netherlands", "Netherlands"], "y": [2740.8, 278.72, 7388.5499999999965, 131.75, 903.3699999999998, 2816.85, 35.40000000000001, 1072.7599999999998, 9061.949999999997, 1167.0, 3468.0, 3166.35]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('06ed558c-4d2e-41c5-b5c0-7d9a649cde70');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
table_prod_country = data.loc[(data['Country'].isin(country_list)) &\
         data['Description'].isin(product_list)
         ,['Country','Description','Revenue']].groupby(['Country','Description'],as_index=False).agg({'Revenue':'sum'})

# %% [markdown]
# ## 6. Create an interactive line chart showing quantity sold by day for the United Kingdom. Add drop-down boxes for Year and Month that allow you to filter the date range that appears in the chart.

# %%
uk = data[data['Country']=='United Kingdom']
uk['Year'] = pd.DatetimeIndex(uk['InvoiceDate']).year
uk['Month'] = pd.DatetimeIndex(uk['InvoiceDate']).month
uk['Day'] = pd.DatetimeIndex(uk['InvoiceDate']).day

# %%
from plotly import graph_objs as go
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
uk.pivot_table(index = ('InvoiceDate'),values = 'Quantity',aggfunc = 'sum').reset_index().head()
# Out:
#           InvoiceDate  Quantity
# 0 2010-12-01 08:26:00        40
# 1 2010-12-01 08:28:00        12
# 2 2010-12-01 08:34:00        98
# 3 2010-12-01 08:35:00         3
# 4 2010-12-01 09:00:00        80

# %%
# With the interact @ we define the two variables that will have a dropdown menu
@interact(Year=list(uk['Year'].unique()), 
          Month=list(uk['Month'].unique()))

# We have to keep in mind that by default it will select a month and a year, its not that we can do multiselection
def line(Year, Month):
    uk_filtered = uk[(uk['Month']==Month) & 
              (uk['Year']==Year)]
    
    uk_filtered.pivot_table(index = ('Day'),values = 'Quantity',aggfunc = 'sum').iplot(kind = 'line',
                                                                                 xTitle = 'Dates',
                                                                                 yTitle = 'Qty Sold',
                                                                                 title = 'Units Sold by date in UK')
# Out:
# interactive(children=(Dropdown(description='Year', options=(2010, 2011), value=2010), Dropdown(description='Mo…

# %% [markdown]
# ## 7. Create an interactive scatter plot that plots number of invoices (x-axis) vs. number of customers (y-axis) and the plot points represent individual products. Add two sliders that control the x and y axis ranges.

# %%
agg_func = {'InvoiceNo':'nunique',
            'CustomerID':'nunique'}

products = uk.groupby('Description').agg(agg_func).reset_index()

# %%
# I am reducing the product Series because otherwise it takes ages to execute
product_list = ['JUMBO BAG RED RETROSPOT', 
                'CREAM HANGING HEART T-LIGHT HOLDER',
                'REGENCY CAKESTAND 3 TIER']

# %%
products.head()
# Out:
#                       Description  InvoiceNo  CustomerID
# 0   4 PURPLE FLOCK DINNER CANDLES         35          30
# 1   50'S CHRISTMAS GIFT BAG LARGE        100          98
# 2               DOLLY GIRL BEAKER        100          77
# 3     I LOVE LONDON MINI BACKPACK         55          46
# 4         NINE DRAWER OFFICE TIDY         25          24

# %%
# With the interact @ we kind of define a variable that the plot will look at when creating the boundaries
@interact(bins_x = (0, len(products['InvoiceNo'])),
          bins_y = (0, len(products['CustomerID'])))

def scatter(bins_x,bins_y):
    products[products['Description'].isin(product_list)].pivot_table(index = 'Description'
                                ,values = ('InvoiceNo','CustomerID')
                                ,aggfunc = 'sum').reset_index().iplot(kind = 'scatter' ,
                                                                      x = 'InvoiceNo',
                                                                      y = 'CustomerID',
                                                                     categories='Description')
# Out:
# interactive(children=(IntSlider(value=1810, description='bins_x', max=3620), IntSlider(value=1810, description…

# %% [markdown]
# ## 8. Creat an interactive bar chart that shows revenue by product description. Add a text field widget that filters the results to show the product that contain the text entered in their description.

# %%
# Again to reduce computational use, I am gonna filter by three products
product_list = ['JUMBO BAG RED RETROSPOT', 
                'CREAM HANGING HEART T-LIGHT HOLDER',
                'REGENCY CAKESTAND 3 TIER']

# %%
@interact(Product='')

def chart(Product):
    data_product = data[data['PaymentMethod'].str.contains(Payment)]
    data = data.groupby('TenureLevel').agg({'MonthlyCharges':'sum'}).reset_index()
    custom_dict = {'New': 0, 'Regular': 1, 'Loyal': 2, 'Very Loyal' : 3}  
    data = data.iloc[data['TenureLevel'].map(custom_dict).argsort()].set_index('TenureLevel')
    
    data.iplot(kind='bar', xTitle='Values')
    data.loc[data['Description'].isin(product_list)].pivot_table(index = 'Description', 
                                                             values = 'Revenue', 
                                                             aggfunc = 'sum').reset_index().iplot(kind = 'bar',
                                                                                                  x = 'Description',
                                                                                                  y = 'Revenue',
                                                                                                  xTitle = 'Product',
                                                                                                  yTitle = 'Revenues',
                                                                                                  title = 'Revenues by product')
# Out:
# <div>
#
#
#             <div id="4765255b-742b-4705-a116-c759f383abe9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4765255b-742b-4705-a116-c759f383abe9")) {
#                     Plotly.newPlot(
#                         '4765255b-742b-4705-a116-c759f383abe9',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Revenue", "orientation": "v", "text": "", "type": "bar", "uid": "75bc9e4a-8d78-4f79-b3d3-287dc7904e59", "x": ["CREAM HANGING HEART T-LIGHT HOLDER", "JUMBO BAG RED RETROSPOT", "REGENCY CAKESTAND 3 TIER"], "y": [100603.49999999866, 85220.78000000192, 142567.44999999963]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Revenues by product"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Product"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Revenues"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('4765255b-742b-4705-a116-c759f383abe9');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
